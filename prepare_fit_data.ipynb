# %%
import os
import sys
import pandas as pd
import numpy as np
import pickle
from scripts.experiments import Experiment

# %%
exp = Experiment(exp_name="base", cluster=False)

# %%
exp.prepare_bin_edges(cols=None, nbin_loc = 6, nbin_ci = 6, nbin_conf=6)

# %%
fit_data_path = os.path.join(exp.data_handler.data_path, exp.exp_config['NLL_method'] + str(exp.exp_config['nfold_CV']))
fit_data_path

# %%
# check the bin edges
bin_data = pickle.load(open(os.path.join(fit_data_path, 'beh_bin_sub_2.pkl'), 'rb'))
bin_data
